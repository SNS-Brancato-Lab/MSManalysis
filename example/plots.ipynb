# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as mcolors

mm=0.1/2.54

mpl.rcParams['figure.dpi'] = 600
mpl.rcParams['figure.figsize'] = (120*mm, 90*mm)
mpl.rcParams['font.size'] = 7.0
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif']='Arial'
mpl.rcParams['font.weight'] = 'bold'

mpl.rcParams.update({'figure.autolayout': True})
mpl.rcParams['figure.titlesize'] = 7
mpl.rcParams['axes.facecolor'] = 'white'
mpl.rcParams['lines.linewidth'] = 1.0
mpl.rcParams['axes.linewidth'] = 0.75
mpl.rcParams['axes.titlesize'] = 7
mpl.rcParams['axes.labelsize'] = 7
mpl.rcParams['axes.labelweight'] = 'normal'
mpl.rcParams['axes.labelpad'] = 1
mpl.rcParams['axes.grid'] = 'False'
mpl.rcParams['axes.axisbelow'] = 'line'

mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.major.size'] = 3
mpl.rcParams['xtick.minor.size'] = 1.5
mpl.rcParams['xtick.major.width'] = 0.4
mpl.rcParams['xtick.minor.width'] = 0.4
mpl.rcParams['xtick.major.pad'] = 4
mpl.rcParams['xtick.labelsize'] = 7

mpl.rcParams['ytick.right'] = 'True'
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.major.size'] = 3
mpl.rcParams['ytick.minor.size'] = 1.5
mpl.rcParams['ytick.major.width'] = 0.4
mpl.rcParams['ytick.minor.width'] = 0.4
mpl.rcParams['ytick.major.pad'] = 4
mpl.rcParams['ytick.labelsize'] = 7
mpl.rcParams['legend.fontsize'] = 7

mpl.rcParams['axes.titleweight'] = 'bold'
mpl.rcParams['axes.labelweight'] = 'bold'
rc = mpl.rcParams
#print(rc.keys())

import json

# %%
cd /home/lucab/Desktop/to_publish/MSManalysis/
# Out:
# /home/lucab/Desktop/to_publish/MSManalysis

# %%
from src.MarkovStates import System

MSM = System()


MSM.load_centers('example/centers_22.pkl')
#fig, ax = plt.subplots(1,1, figsize=(120*mm,120*mm))
MSM.load_models('example/models_35.pkl')
MSM.plot_its(4)
#plt.show()
# Out:
# Loading Centers from example/centers_22.pkl
# Centers loaded.
#
#
# ### Microstate Info: ###
# Number of microstates: 22
# Microstate Tab:
# -------------  ----  ----
# Microstate 0   0.99  4.96
# Microstate 1   2.96  3
# Microstate 2   1.98  3.94
# Microstate 3   0     5.86
# Microstate 4   3.95  1.99
# Microstate 5   0.99  4.88
# Microstate 6   0     5.94
# Microstate 7   1.98  3.98
# Microstate 8   2.97  2.94
# Microstate 9   2.96  3.05
# Microstate 10  0.99  5.02
# Microstate 11  1.98  4.04
# Microstate 12  1.37  5.75
# Microstate 13  3.19  4.03
# Microstate 14  1.98  3.91
# Microstate 15  2.96  2.97
# Microstate 16  0     6
# Microstate 17  0.23  6.83
# Microstate 18  0.99  4.92
# Microstate 19  0.11  5.88
# Microstate 20  3.95  2.04
# Microstate 21  0     5.9
# -------------  ----  ----
#
# Loading Models from example/models_35.pkl
# Models loaded.
#
# <class 'src.tools.types.Models'>
#
# Plotting implied time scales!

# %%
MSM.select_model(4000)
MSM.ck_test(5)
# Out:
# Lagtimes go from 100 step(s) to 10000 steps every 100 step(s).
# Choosing model number 39 with lagtime 4000.
# Performing Chapman-Kolmogorov test with 5 metastable sets.
